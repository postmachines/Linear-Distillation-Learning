# %%
import pandas as pd
pd.set_option('max_columns', 50)

# %%
df = pd.read_csv('results/02-02-2021/results_covtype_o2m.csv')

# %%
df.sort_values(by=['accuracy'])
# Out:
#     dataset  epochs  way  train_shot  test_shot   dld optimizer       lr  \
# 4   covtype       3    7           1          2  True      adam  0.00005
# 8   covtype       3    7           5          2  True      adam  0.00005
# 3   covtype       3    7           1          2  True      adam  0.00010
# 24  covtype      10    7           1          2  True      adam  0.00005
# 7   covtype       3    7           5          2  True      adam  0.00010
# 23  covtype      10    7           1          2  True      adam  0.00010
# 28  covtype      10    7           5          2  True      adam  0.00005
# 12  covtype       3    7          10          2  True      adam  0.00005
# 2   covtype       3    7           1          2  True      adam  0.00100
# 11  covtype       3    7          10          2  True      adam  0.00010
# 27  covtype      10    7           5          2  True      adam  0.00010
# 32  covtype      10    7          10          2  True      adam  0.00005
# ...

# %%
df2 = pd.read_csv('results/02-02-2021/results_covtype_bidir.csv')

# %%
df2.sort_values(by=['accuracy'])
# Out:
#     dataset  train_shot  x_dim  way  test_shot       loss  epochs  trials  \
# 8   covtype           1     54    7          1  MSELoss()      10     100
# 7   covtype           1     54    7          1  MSELoss()      10     100
# 5   covtype           1     54    7          1  MSELoss()      10     100
# 17  covtype          10     54    7          1  MSELoss()      10     100
# 4   covtype           1     54    7          1  MSELoss()      10     100
# 16  covtype          10     54    7          1  MSELoss()      10     100
# 6   covtype           1     54    7          1  MSELoss()      10     100
# 3   covtype           1     54    7          1  MSELoss()      10     100
# 14  covtype          10     54    7          1  MSELoss()      10     100
# 13  covtype          10     54    7          1  MSELoss()      10     100
# 2   covtype           1     54    7          1  MSELoss()      10     100
# 1   covtype           1     54    7          1  MSELoss()      10     100
# ...

# %%
df3 = pd.read_csv('results/02-02-2021/results_covtype_logreg.csv')

# %%
df3.sort_values(by=['accuracy'])
# Out:
#     dataset  epochs  way  train_shot  test_shot  x_dim optimizer       lr  \
# 5   covtype       3    7          10          1     54      adam  0.00005
# 4   covtype       3    7          10          1     54      adam  0.00010
# 23  covtype      10    7          10          1     54      adam  0.00005
# 22  covtype      10    7          10          1     54      adam  0.00010
# 11  covtype       3    7         100          1     54      adam  0.00005
# 14  covtype       3    7         200          1     54      adam  0.00005
# 1   covtype       3    7           1          1     54      adam  0.00010
# 2   covtype       3    7           1          1     54      adam  0.00005
# 20  covtype      10    7           1          1     54      adam  0.00005
# 0   covtype       3    7           1          1     54      adam  0.00100
# 19  covtype      10    7           1          1     54      adam  0.00010
# 3   covtype       3    7          10          1     54      adam  0.00100
# ...

# %%
df4 = pd.read_csv('results/02-02-2021/results_covtype_tree.csv')

# %%
df4.sort_values(by=['accuracy'])
# Out:
#     dataset  way  train_shot  test_shot  max_depth  x_dim  channels  trials  \
# 0   covtype    7           1          1          1     54         0     100
# 1   covtype    7           1          1          3     54         0     100
# 2   covtype    7           1          1          5     54         0     100
# 4   covtype    7           1          1         10     54         0     100
# 7   covtype    7           1          1         50     54         0     100
# 6   covtype    7           1          1         30     54         0     100
# 3   covtype    7           1          1          7     54         0     100
# 5   covtype    7           1          1         20     54         0     100
# 9   covtype    7          10          1          1     54         0     100
# 8   covtype    7           1          1        100     54         0     100
# 18  covtype    7          50          1          1     54         0     100
# ...

# %%
df5 = pd.read_csv('results/02-02-2021/results_covtype_mlp.csv')

# %%
df5.sort_values(by=['accuracy'])
# Out:
#    dataset  epochs  way  train_shot  test_shot  x_dim  hidden_size  \
# 2  covtype       5    7           1          1     54          256
# 1  covtype       5    7           1          1     54          256
# 5  covtype       5    7          10          1     54          256
# 0  covtype       5    7           1          1     54          256
# 4  covtype       5    7          10          1     54          256
# 8  covtype       5    7          50          1     54          256
# 3  covtype       5    7          10          1     54          256
# 7  covtype       5    7          50          1     54          256
# 9  covtype       5    7         100          1     54          256
# 6  covtype       5    7          50          1     54          256
#
#    hidden_layers nonlinearity optimizer       lr  channels  \
# 2              2         relu      adam  0.00005         3
# 1              2         relu      adam  0.00010         3
# ...
