# %%
import pandas as pd
pd.set_option('max_columns', 50)

# %%
df = pd.read_csv('results/02-02-2021/results_customer_o2m.csv')

# %%
df.sort_values(by=['accuracy'])
# Out:
#      dataset  epochs  way  train_shot  test_shot   dld optimizer       lr  \
# 15  customer       3  2.0         100          1  True      adam  0.00005
# 40  customer       3  NaN           1          1  True      adam  0.00010
# 43  customer       3  NaN           1          1  True      adam  0.00010
# 11  customer       3  2.0          10          1  True      adam  0.00005
# 44  customer       3  NaN           1          1  True      adam  0.00005
# 27  customer      10  2.0           5          1  True      adam  0.00005
# 6   customer       3  2.0           5          1  True      adam  0.00010
# 7   customer       3  2.0           5          1  True      adam  0.00005
# 10  customer       3  2.0          10          1  True      adam  0.00010
# 14  customer       3  2.0         100          1  True      adam  0.00010
# 26  customer      10  2.0           5          1  True      adam  0.00010
# 30  customer      10  2.0          10          1  True      adam  0.00010
# ...

# %%
df2 = pd.read_csv('results/02-02-2021/results_customer_bidir.csv')

# %%
df2.sort_values(by=['accuracy'])
# Out:
#      dataset  train_shot  test_shot       loss  epochs  trials  silent split  \
# 17  customer          10          1  MSELoss()      10     100    True  test
# 16  customer          10          1  MSELoss()      10     100    True  test
# 13  customer          10          1  MSELoss()      10     100    True  test
# 14  customer          10          1  MSELoss()      10     100    True  test
# 4   customer           1          1  MSELoss()      10     100    True  test
# 5   customer           1          1  MSELoss()      10     100    True  test
# 7   customer           1          1  MSELoss()      10     100    True  test
# 8   customer           1          1  MSELoss()      10     100    True  test
# 3   customer           1          1  MSELoss()      10     100    True  test
# 6   customer           1          1  MSELoss()      10     100    True  test
# 35  customer         100          1  MSELoss()      10     100    True  test
# ...
